# %%
# sst_admission.py
from tabulate import tabulate

# Raw data parsed into a list of dictionaries
data = [
    {"Name": "Pulasari", "User ID": "5535590", "10th Score": 92.2, "12th Score": 83.2, "JEE Mains": 67.33, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "", "Tech Projects": 2, "Math Score": 79},
    {"Name": "Gauri", "User ID": "5716520", "10th Score": 91.2, "12th Score": 84.5, "JEE Mains": 95.43, "JEE Advance": 0, "BITSAT": 214, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 84},
    {"Name": "Deepika", "User ID": "5484961", "10th Score": 66.4, "12th Score": 85.2, "JEE Mains": 95.13, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 98},
    {"Name": "Raima", "User ID": "5719547", "10th Score": 90.8, "12th Score": 89.75, "JEE Mains": 77.21, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "", "Tech Projects": 1, "Math Score": 84},
    {"Name": "Pranav", "User ID": "5598188", "10th Score": 96.5, "12th Score": 97.1, "JEE Mains": 90, "JEE Advance": 0, "BITSAT": 256, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 99.66},
    {"Name": "Arnav Kulshreshtha", "User ID": "5653672", "10th Score": 95, "12th Score": 97, "JEE Mains": 0, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 95},
    {"Name": "Harshavardhan", "User ID": "5433743", "10th Score": 99.04, "12th Score": 81.2, "JEE Mains": 86.52, "JEE Advance": 21.56, "BITSAT": 0, "Codechef": 1005, "Olympiad": "City / Zonal", "Tech Projects": 0, "Math Score": 74},
    {"Name": "Jai", "User ID": "5417192", "10th Score": 75, "12th Score": 75, "JEE Mains": 97.08, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 80},
    {"Name": "Rounak", "User ID": "5137882", "10th Score": 77, "12th Score": 85, "JEE Mains": 70, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "International", "Tech Projects": 2, "Math Score": 0},  # B+ = 85%
    {"Name": "Jay", "User ID": "5130838", "10th Score": 96.4, "12th Score": 93.6, "JEE Mains": 66.12, "JEE Advance": 0, "BITSAT": 0, "Codechef": 900, "Olympiad": "", "Tech Projects": 0, "Math Score": 88},
    {"Name": "Hasini", "User ID": "5569827", "10th Score": 91.6, "12th Score": 95.4, "JEE Mains": 93.4, "JEE Advance": 0, "BITSAT": 187, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 100},
    {"Name": "M Jithendar", "User ID": "5738293", "10th Score": 100, "12th Score": 96.8, "JEE Mains": 89.03, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 96.67},  # 10 CGPA = 100%
    {"Name": "Sk Aktar", "User ID": "3917419", "10th Score": 90, "12th Score": 90, "JEE Mains": 75.99, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "", "Tech Projects": 1, "Math Score": 0},  # A = 90%
    {"Name": "Mohammad Hamza", "User ID": "5771128", "10th Score": 91, "12th Score": 87.8, "JEE Mains": 97.5, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 87},
    {"Name": "Prathinav", "User ID": "5227133", "10th Score": 86.8, "12th Score": 63.6, "JEE Mains": 55, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "City / Zonal", "Tech Projects": 0, "Math Score": 70},
    {"Name": "Keshav", "User ID": "5395532", "10th Score": 91.2, "12th Score": 81.6, "JEE Mains": 95.05, "JEE Advance": 29.72, "BITSAT": 230, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 80},
    {"Name": "Nitya", "User ID": "5500727", "10th Score": 87.34, "12th Score": 83.4, "JEE Mains": 0, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "International", "Tech Projects": 0, "Math Score": 70},
    {"Name": "Roshni", "User ID": "5766555", "10th Score": 100, "12th Score": 97.8, "JEE Mains": 0, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 100},  # 10 CGPA = 100%
    {"Name": "Ananya", "User ID": "5776129", "10th Score": 95.8, "12th Score": 96.1, "JEE Mains": 0, "JEE Advance": 0, "BITSAT": 0, "Codechef": 1653, "Olympiad": "", "Tech Projects": 0, "Math Score": 99},
    {"Name": "Vaishnavi", "User ID": "5420545", "10th Score": 97, "12th Score": 96.33, "JEE Mains": 88, "JEE Advance": 0, "BITSAT": 312, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 94},
    {"Name": "Binay", "User ID": "5652653", "10th Score": 81, "12th Score": 65, "JEE Mains": 0, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "City / Zonal", "Tech Projects": 1, "Math Score": 66},
    {"Name": "Kumari Khushi", "User ID": "5597639", "10th Score": 95, "12th Score": 91, "JEE Mains": 0, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 61},
    {"Name": "Joshiya Vijaya", "User ID": "5737057", "10th Score": 94.4, "12th Score": 92.8, "JEE Mains": 0, "JEE Advance": 0, "BITSAT": 0, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 91},
    {"Name": "Niksha", "User ID": "5738477", "10th Score": 99.4, "12th Score": 91.4, "JEE Mains": 91.55, "JEE Advance": 0, "BITSAT": 207, "Codechef": 0, "Olympiad": "", "Tech Projects": 0, "Math Score": 93},
]

# Task 1: Shortlisting Criteria
def calculate_entrance_score(student):
    # Use the highest available entrance score (normalize BITSAT and Codechef to 100 scale)
    jee_mains = student["JEE Mains"]
    jee_advance = student["JEE Advance"]
    bitsat = student["BITSAT"] / 360 * 100 if student["BITSAT"] > 0 else 0  # BITSAT max score ~360
    codechef = student["Codechef"] / 3000 * 100 if student["Codechef"] > 0 else 0  # Codechef max ~3000
    return max(jee_mains, jee_advance, bitsat, codechef)

def calculate_tech_score(student):
    tech_count = student["Tech Projects"]
    if student["Olympiad"] == "International":
        tech_count += 2
    elif student["Olympiad"] in ["City / Zonal"]:
        tech_count += 1
    if student["Codechef"] > 1000 or student["BITSAT"] > 200:
        tech_count += 1
    return min(tech_count, 3) * 10  # Cap at 30 points (3 achievements)

def calculate_total_score(student):
    entrance = calculate_entrance_score(student)
    tech = calculate_tech_score(student)
    score = (student["10th Score"] * 0.2) + (student["12th Score"] * 0.3) + (entrance * 0.3) + tech
    return round(score, 2)

def assign_tier(score):
    if score >= 85:
        return "Tier 1"
    elif score >= 70:
        return "Tier 2"
    elif score >= 50:
        return "Tier 3"
    return "Not Shortlisted"

# Calculate scores and tiers
for student in data:
    student["Entrance Score"] = calculate_entrance_score(student)
    student["Tech Score"] = calculate_tech_score(student)
    student["Total Score"] = calculate_total_score(student)
    student["Tier"] = assign_tier(student["Total Score"])

# Sort by score (descending) and shortlist top 15
shortlisted = sorted(data, key=lambda x: x["Total Score"], reverse=True)[:15]

# Task 2: Interview Scheduling
interviewers = ["Interviewer 1", "Interviewer 2", "Interviewer 3"]
time_slots = ["9:00–9:30", "9:30–10:00", "10:00–10:30", "10:30–11:00", "11:00–11:30"]

def schedule_interviews(students, round_num):
    schedule = {slot: {interviewer: "" for interviewer in interviewers} for slot in time_slots}
    student_idx = 0
    for slot in time_slots:
        for interviewer in interviewers:
            if student_idx < len(students):
                schedule[slot][interviewer] = f"{students[student_idx]['Name']} ({students[student_idx]['Tier']})"
                student_idx += 1
    return schedule

# Assumptions: Round 2 reshuffles students for fairness
round1_schedule = schedule_interviews(shortlisted, 1)
round2_students = shortlisted[::-1]  # Reverse order for Round 2
round2_schedule = schedule_interviews(round2_students, 2)

# Generate Output as Markdown
output = "# SST UG Admission Task – March 2025\n\n"

# Task 1: Shortlisting Criteria
output += "## Shortlisting Criteria\n"
output += "Students are evaluated on a total score (out of 100):\n"
output += "- **10th Board Score**: 20% (normalized to percentage)\n"
output += "- **12th Board Score**: 30% (normalized to percentage)\n"
output += "- **Entrance Exam Score**: 30% (highest of JEE Mains percentile, JEE Advanced %, BITSAT scaled to 100, Codechef scaled to 100; 0 if missing)\n"
output += "- **Technical Achievements**: Up to 30 points (10 points per achievement: projects, Olympiads, Codechef > 1000, BITSAT > 200; max 3)\n"
output += "- **Tiebreaker**: Higher Math Score\n\n"
output += "### Tiers\n"
output += "- Tier 1: Score ≥ 85 (Top performers)\n"
output += "- Tier 2: Score 70–84 (Strong candidates)\n"
output += "- Tier 3: Score 50–69 (Eligible but lower priority)\n"
output += "- Shortlist: Top 15 students (~60% of 24, scalable to 1000)\n\n"
output += "### Assumptions and Considerations\n"
output += "- Grades normalized: 10 CGPA = 100%, A = 90%, B+ = 85%\n"
output += "- Missing entrance scores assigned 0\n"
output += "- BITSAT scaled (out of 360), Codechef scaled (out of 3000)\n"
output += "- Tech achievements capped at 3 for fairness\n"
output += "- Scalable: Scoring and sorting logic applies to any dataset size\n\n"

# Shortlisted Students
output += "## Shortlisted Students\n"
table_data = [[s["Name"], s["User ID"], s["Total Score"], s["Tier"]] for s in shortlisted]
output += tabulate(table_data, headers=["Name", "User ID", "Score", "Tier"], tablefmt="github") + "\n\n"

# Task 2: Interview Schedule
output += "## Interview Schedule\n"
output += "### Assumptions and Considerations\n"
output += "- Each interview is 30 minutes\n"
output += "- 3 interviewers, each available 3 hours/day (6 slots/day, 18 total)\n"
output += "- Round 1 and Round 2 on separate days\n"
output += "- Round 2 reshuffles students for balanced interviewer exposure\n\n"
output += "### Round 1 – Day 1\n"
table_data = [(slot, *(round1_schedule[slot][i] for i in interviewers)) for slot in time_slots]
output += tabulate(table_data, headers=["Time"] + interviewers, tablefmt="github") + "\n\n"
output += "### Round 2 – Day 2\n"
table_data = [(slot, *(round2_schedule[slot][i] for i in interviewers)) for slot in time_slots]
output += tabulate(table_data, headers=["Time"] + interviewers, tablefmt="github") + "\n"

# Save to file
with open("sst_admission_output.md", "w") as f:
    f.write(output)

print("Output saved to 'sst_admission_output.md'.")
# Out:
# Output saved to 'sst_admission_output.md'.
